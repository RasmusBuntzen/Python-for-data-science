# %% [markdown]
# # Dette er en header

# %% [markdown]
# Dette er markdown

# %%
print("Dette er kode")
# Out:
# Dette er kode

# %% [markdown]
# ![Jupyter%20notebooks%20%C3%B8velse.PNG](attachment:Jupyter%20notebooks%20%C3%B8velse.PNG)

# %%
# %cd C:\Users\Rasmus\Google Drive\Uni\År 2\Blok 1\Pyhthon for data science\Projekter\Øvelser
# Out:
# C:\Users\Rasmus\Google Drive\Uni\År 2\Blok 1\Pyhthon for data science\Projekter\Øvelser

# %%
import pandas as pd

# %%
data = pd.read_table("british-english.txt")
data
# Out:
#               A
# 0           A's
# 1           AMD
# 2         AMD's
# 3           AOL
# 4         AOL's
# ...         ...
# 101819   épée's
# 101820    épées
# 101821    étude
# 101822  étude's
# 101823   études
#
# [101824 rows x 1 columns]

# %%
grouped_data = data.groupby(data.A.str[0]) #Grupere efter første bogstav i ordet
grouped_data.groups.keys() #Viser alle keysne i grupperne ( første bogstav i ordet)
for A,grp in grouped_data: #Laver et loop der viser alle gruperne
    print(grp)
# Out:
#               A
# 0           A's
# 1           AMD
# 2         AMD's
# 3           AOL
# 4         AOL's
# ...         ...
# 1398    Aztecan
# 1399  Aztecan's
# 1400     Aztecs
# 1401     Aztlan
# 1402   Aztlan's
#
# [1403 rows x 1 columns]
#                 A
# 1403            B
# 1404          B's
# 1405          BBB
# 1406        BBB's
# 1407          BMW
# ...           ...
# 2854    Byzantine
# 2855  Byzantine's
# 2856   Byzantines
# 2857    Byzantium
# 2858  Byzantium's
#
# [1456 rows x 1 columns]
#                       A
# 2859                  C
# 2860                C's
# 2861                CVS
# 2862              CVS's
# 2863                 Ca
# ...                 ...
# 4436  Czechoslovakian's
# 4437   Czechoslovakians
# 4438             Czechs
# 4439             Czerny
# 4440           Czerny's
#
# [1582 rows x 1 columns]
#                  A
# 4441             D
# 4442           D's
# 4443         Dacca
# 4444       Dacca's
# 4445        Dachau
# ...            ...
# ...
